# %%
from utils import *
import numpy as np
import polars as pl
import matplotlib.pyplot as plt
import torch
from torch import nn
from torch.utils.data import DataLoader

# %%
device = torch.accelerator.current_accelerator().type if torch.accelerator.is_available() else "cpu"
print(f"Using {device} device")
# Out:
# Using mps device

# %% [markdown]
# ## Linear Regression

# %%
X, Y, C = load_brca_data()

loss_fn = torch.nn.BCELoss()
model = LogisticRegression(n_features=X.shape[1], output_dim=1)
optimizer = torch.optim.SGD(model.parameters(), lr=1e-3)

full_dataset = BRCADataset()

training_data, test_data = torch.utils.data.random_split(full_dataset, [0.8, 0.2])
train_dataloader = DataLoader(training_data, batch_size=50)
test_dataloader = DataLoader(test_data, batch_size=50)

epochs = 10
for t in range(epochs):
    print(f"Epoch {t+1}\n-------------------------------")
    train(train_dataloader, model, loss_fn, optimizer, device)
    test_loss = test(test_dataloader, model, loss_fn, device)
print("Done!")

print("Loss:", test_loss.item())
print("RMSD:", np.sqrt(test_loss.item()))
# Out:
# Epoch 1
# -------------------------------
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 16
#      12
#      13 epochs = 10
#      14 for t in range(epochs):
#      15     print(f"Epoch {t+1}\n-------------------------------")
# ---> 16     train(train_dataloader, model, loss_fn, optimizer, device)
#      17     test_loss = test(test_dataloader, model, loss_fn, device)
#      18 print("Done!")
#      19
#
# File ~/Library/Mobile Documents/com~apple~CloudDocs/PhD/Machine Learning/project/code/utils.py:265, in train(dataloader, model, loss_fn, optimizer, device)
#     263 size = len(dataloader.dataset)
#     264 model.train()
# --> 265 for batch, (X, y) in enumerate(dataloader):
#     266     X, y = X.to(device), y.to(device)
#     268     # Compute prediction error
#
# ...

# %%
full_dataset.Y.reshape((1904,1))
# Out:
# array([1])
